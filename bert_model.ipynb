# %% [markdown]
# <a href="https://colab.research.google.com/github/Navdeepbhatt/AI-Based-Exam-Anxiety-Detector/blob/main/bert_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Mar  6 21:54:54 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/Navdeepbhatt/AI-Based-Exam-Anxiety-Detector.
# %cd AI-Based-Exam-Anxiety-Detector
# !pwd
# !ls
# !pip install -r requirements.txt
# !ls notebooks/
# Out:
# Cloning into 'AI-Based-Exam-Anxiety-Detector.'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'AI-Based-Exam-Anxiety-Detector'
# /content/AI-Based-Exam-Anxiety-Detector
# /content/AI-Based-Exam-Anxiety-Detector
# backend  data  notebooks  README.md  requirements.txt
# ...
# eda.py
